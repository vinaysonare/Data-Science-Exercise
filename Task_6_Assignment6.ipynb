# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %% [markdown]
# # Assignment6

# %% [markdown]
# ## Brain vs. Body Weight
#
# In the file `brain_body.txt`, the average brain and body weight for a number of mammal species are recorded. Load this data into a Pandas data frame.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data for brain weight to body weight.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)

# %%
df = pd.read_fwf("brain_body.txt")

# %%
df.head()
# Out:
#      Brain   Body
# 0    3.385   44.5
# 1    0.480   15.5
# 2    1.350    8.1
# 3  465.000  423.0
# 4   36.330  119.5

# %%
x = df['Body']
x = x.to_frame()
y = df['Brain']
lReg = linear_model.LinearRegression()
lReg.fit(x, y)
print('Intercept:', lReg.intercept_)
print('Coefficient:',lReg.coef_)
# Out:
# Intercept: -56.85554542859637
# Coefficient: [0.90291295]

# %%
plt.scatter(x, y, color='g')
plt.plot(x, lReg.predict(x))
plt.xlabel('Body')
plt.ylabel('Chirps/Second')
plt.title('Body vs Brain Chart')
# Out:
# Text(0.5, 1.0, 'Body vs Brain Chart')

# %%
print('Score:', lReg.score(x, y))
# Out:
# Score: 0.8726620843043331

# %% [markdown]
# **Here R-squared value is more than 0.8 which means the equation is a good fit for this data**
